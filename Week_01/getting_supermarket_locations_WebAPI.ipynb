# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import folium
from pandas import json_normalize

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/Week_01

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)

# Number of rows and columns
print(df.shape)

# First rows
df.head()
# Out:
# (3438, 265)
#    type        id        lat       lon tags.brand tags.brand:wikidata  \
# 0  node  33126515  47.155616  9.037915       Spar             Q610492
# 1  node  36726161  47.226191  8.980329     Migros             Q680727
# 2  node  39768209  47.225154  8.969868       Coop             Q432564
# 3  node  39947904  47.376732  8.542161       Coop             Q432564
# 4  node  48932835  47.375020  8.522895     Migros             Q680727
#
#   tags.brand:wikipedia tags.name  \
# 0   en:SPAR (retailer)      Spar
# 1            de:Migros    Migros
# 2                  NaN      Coop
# 3    de:Coop (Schweiz)      Coop
# 4                  NaN    Migros
#
#                                   tags.opening_hours    tags.shop  ...  \
# 0  Mo-Th 08:00-19:00; Fr 08:00-20:00; Sa 08:00-17:00  supermarket  ...
# 1  Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 07:30-17...  supermarket  ...
# 2                                                NaN  supermarket  ...
# 3                                  Mo-Sa 06:00-22:00  supermarket  ...
# 4                          Mo-Sa 08:00-21:00; PH off  supermarket  ...
#
#   tags.diet:organic tags.diet:seafood tags.brand:website  \
# 0               NaN               NaN                NaN
# 1               NaN               NaN                NaN
# 2               NaN               NaN                NaN
# 3               NaN               NaN                NaN
# 4               NaN               NaN                NaN
#
#   tags.recycling:low_energy_bulbs tags.image tags.opening_hours:cafe  \
# 0                             NaN        NaN                     NaN
# 1                             NaN        NaN                     NaN
# 2                             NaN        NaN                     NaN
# 3                             NaN        NaN                     NaN
# 4                             NaN        NaN                     NaN
#
#   tags.currency:XBT tags.payment:lightning tags.payment:lightning_contactless  \
# 0               NaN                    NaN                                NaN
# 1               NaN                    NaN                                NaN
# 2               NaN                    NaN                                NaN
# 3               NaN                    NaN                                NaN
# 4               NaN                    NaN                                NaN
#
#   tags.payment:onchain
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 265 columns]

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Migros', 'Coop'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                  popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#          lat       lon tags.brand    tags.shop
# 1  47.226191  8.980329     Migros  supermarket
# 2  47.225154  8.969868       Coop  supermarket
# 3  47.376732  8.542161       Coop  supermarket
# 4  47.375020  8.522895     Migros  supermarket
# 7  47.491874  8.706448     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb629296dd7af78de8d6fc9e340ede9c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb629296dd7af78de8d6fc9e340ede9c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb629296dd7af78de8d6fc9e340ede9c = L.map(
#                 &quot;map_bb629296dd7af78de8d6fc9e340ede9c&quot;,
#                 {
#                     center: [47.00834522940156, 7.994377262532523],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_bb629296dd7af78de8d6fc9e340ede9c);
#
#
#
#
#
#             var tile_layer_a982321f91ba6d010d093c2080ae0ce6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a982321f91ba6d010d093c2080ae0ce6.addTo(map_bb629296dd7af78de8d6fc9e340ede9c);
#
#
#             var marker_9afd3b740bea302ed82747f0913ce8cb = L.marker(
#                 [47.2261912, 8.9803292],
#                 {}
#             ).addTo(map_bb629296dd7af78de8d6fc9e340ede9c);
#
#
#         var popup_b675c5359c92b1f136751ad0e6efc6c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ae0bc19afd6ed61dff16c8fcd458ca8f = $(`&lt;div id=&quot;html_ae0bc19afd6ed61dff16c8fcd458ca8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_b675c5359c92b1f136751ad0e6efc6c3.setContent(html_ae0bc19afd6ed61dff16c8fcd458ca8f);
#
#
#
#         marker_9afd3b740bea302ed82747f0913ce8cb.bindPopup(popup_b675c5359c92b1f136751ad0e6efc6c3)
#         ;
#
#
#
#
#             var marker_921e6270168d61dfc1d24a8c085724da = L.marker(
#                 [47.2251539, 8.9698681],
#                 {}
#             ).addTo(map_bb629296dd7af78de8d6fc9e340ede9c);
#
#
#         var popup_4e59808785cc61d6c4e9ac72ac36cbe6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ef8f6682c48c83453a76fbe01b4e0f4f = $(`&lt;div id=&quot;html_ef8f6682c48c83453a76fbe01b4e0f4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_4e59808785cc61d6c4e9ac72ac36cbe6.setContent(html_ef8f6682c48c83453a76fbe01b4e0f4f);
#
#
#
#         marker_921e6270168d61dfc1d24a8c085724da.bindPopup(popup_4e59808785cc61d6c4e9ac72ac36cbe6)
#         ;
#
#
#
#
#             var marker_1e193306d70abaa9d80d20d9f941b5fe = L.marker(
#                 [47.3767316, 8.5421608],
#                 {}
#             ).addTo(map_bb629296dd7af78de8d6fc9e340ede9c);
#
#
#         var popup_6cd0a8595ea158c86305fe4d92dea92f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_787af62d4282754805b0d84d1f93c54d = $(`&lt;div id=&quot;html_787af62d4282754805b0d84d1f93c54d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_6cd0a8595ea158c86305fe4d92dea92f.setContent(html_787af62d4282754805b0d84d1f93c54d);
#
#
#
#         marker_1e193306d70abaa9d80d20d9f941b5fe.bindPopup(popup_6cd0a8595ea158c86305fe4d92dea92f)
#         ;
#
#
#
#
#             var marker_2de9b2f0514db77450d263a181360515 = L.marker(
#                 [47.37502, 8.522895],
#                 {}
#             ).addTo(map_bb629296dd7af78de8d6fc9e340ede9c);
#
#
#         var popup_2727d79fb2765594b722860685bd1b46 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b9cefe8e61b3929d480988a226224fbd = $(`&lt;div id=&quot;html_b9cefe8e61b3929d480988a226224fbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_2727d79fb2765594b722860685bd1b46.setContent(html_b9cefe8e61b3929d480988a226224fbd);
#
#
#
#         marker_2de9b2f0514db77450d263a181360515.bindPopup(popup_2727d79fb2765594b722860685bd1b46)
#         ;
#
#
#
#
#             var marker_b31d2eeb8d0e59c3b3992867ee0f3ac9 = L.marker(
#                 [47.4918744, 8.7064484],
#                 {}
#             ).addTo(map_bb629296dd7af78de8d6fc9e340ede9c);
#
#
#         var popup_810a7eec2d60512c835be198f6f33784 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1b0e74f3663696fdd99491f32417a046 = $(`&lt;div id=&quot;html_1b0e74f3663696fdd99491f32417a046&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_810a7eec2d60512c835be198f6f33784.setContent(html_1b0e74f3663696fdd99491f32417a046);
#
#
#
#         marker_b31d2eeb8d0e59c3b3992867ee0f3ac9.bindPopup(popup_810a7eec2d60512c835be198f6f33784)
#         ;
#
#
#
#
#             var marker_b5e23193e8781d5b1f95b6809e7160ac = L.marker(
#                 [47.3400698, 8.5305461],
#                 {}

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-1014-azure
# Datetime: 2024-09-24 11:27:52
# Python Version: 3.11.10
# -----------------------------------
